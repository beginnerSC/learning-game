# %% [markdown]
# |Layer	|Size (Inches)|	Size (Centimeters)|	Notes|
# |--|--|--|--|
# |Trunk Piece|	8 inches|	20 cm|	Same as original video|
# |1| (Base)	7 inches|	18 cm|	Original video size|
# |2|	6 inches|	15.5 cm|	Original video size|
# |3|	5.3 inches|	13.5 cm|	Original video size|
# |4|	4.5 inches|	11.5 cm|	Original video size|
# |5|	4 inches|	10 cm|	Original video size|
# |6|	3.5 inches|	9 cm|	New size added|
# |7|	3 inches|	7.5 cm|	New size added|
# |8|	2.75 inches|	7 cm|	New size added|
# |9|	2.5 inches|	6.5 cm|	Original video size|
# |10| (Top)	2 inches|	5 cm|	New size added for the very top|
